# %% [markdown]
# # CME538 — Introduction to Data Science
#
# ## Assignment 1 — Pandas

# %% [markdown]
# ### Learning Objectives
#
# After completing this assignment, you should be able to:
#
# - Load tabular data into Pandas DataFrames.
# - Inspect and describe the structure of a DataFrame.
# - Select, filter, sort, and aggregate data using Pandas.
# - Use `groupby()` to summarize data by categories.
# - Count unique values and frequencies.
# - Perform basic text-based filtering and analysis.
# - Write clear, concise, and reproducible Pandas code.
#
# ### Submission Guidelines
#
# You may add additional cells for exploratory or scratch work while completing the assignment. Before submitting:
#
# - Remove unnecessary scratch cells and outputs.
# - Keep only the code and output needed to answer each question.
# - Do not display entire DataFrames or large outputs unless explicitly requested.
# - Use the variable names specified in each question.
# - Restart the kernel and run the notebook from beginning to end to ensure that all cells execute without errors.
#
# ### Marking Breakdown
#
# | Component | Points |
# |---|---:|
# | Questions 1a–1j | 10 |
# | Questions 2a–2f | 6 |
# | Code Quality | 3 |
# | **Total** | **19** |
#
# ### Code Quality
#
# Code quality will be assessed across the complete notebook.
#
# | Level | Points | Description |
# |---|---:|---|
# | **Developing** | 1 | Code produces the required results but may be difficult to follow, unnecessarily repetitive, poorly organized, or include excessive output. |
# | **Competent** | 2 | Code is organized and readable, uses appropriate Pandas operations, and produces concise, relevant outputs. |
# | **Strong** | 3 | Code is clear, concise, well organized, and reproducible; uses Pandas effectively; avoids unnecessary operations and output; and executes successfully from beginning to end. |

# %% [markdown]
# ## Notebook Setup

# %%
# Import required libraries
import pandas as pd

# %% [markdown]
# ## Question 1 — San Francisco Salaries
#
# For Question 1, you will work with the **SF Salaries** dataset from Kaggle. The dataset contains annual compensation records for employees of the City and County of San Francisco from 2011 to 2014, including employee names, job titles, and various components of compensation.
#
# ### Question 1a — Loading the Dataset
#
# Use Pandas to read `sf_salaries.csv` into a DataFrame named `sf_salaries`. Preview the first five rows of the DataFrame to inspect the dataset.
#
# Then, report the employee names associated with `Id` 1 and `Id` 5.

# %%
# Load the dataset
sf_salaries = ...

# Preview the first five rows
sf_salaries.head()

# %% [markdown]
# #### Question 1a — Answer
#
# - Employee name for `Id = 1`: **[Your answer here]**
# - Employee name for `Id = 5`: **[Your answer here]**

# %% [markdown]
# ------

# %% [markdown]
# ### Question 1b — Inspecting the DataFrame
#
# Use the `.info()` method to inspect the `sf_salaries` DataFrame. Based on the output, determine:
#
# - The number of rows.
# - The number of columns.
# - The unique data types present in the DataFrame.

# %%
# Display a summary of the DataFrame structure and data types
...

# %% [markdown]
# #### Question 1b — Answer
#
# - Number of rows: **[Your answer here]**
# - Number of columns: **[Your answer here]**
# - Unique data types: **[Your answer here]**
#
# -----

# %% [markdown]
# ### Question 1c — Summary Statistics
#
# Calculate the minimum, maximum, and mean values of `BasePay` in the dataset.
#
# Store the results in the following variables:
#
# - `base_pay_min`
# - `base_pay_max`
# - `base_pay_mean`

# %%
# Calculate the minimum, maximum, and mean BasePay
base_pay_min = ...
base_pay_max = ...
base_pay_mean = ...

# Display the results
print(f"Minimum BasePay: {base_pay_min:.2f}")
print(f"Maximum BasePay: {base_pay_max:.2f}")
print(f"Mean BasePay: {base_pay_mean:.2f}")

# %% [markdown]
# #### Question 1c — Answer
#
# - Minimum `BasePay`: **[Your answer here]**
# - Maximum `BasePay`: **[Your answer here]**
# - Mean `BasePay`: **[Your answer here]**
#
# -----

# %% [markdown]
# ### Question 1d — Filtering Records
#
# Find the employee record where `EmployeeName` is `GREGORY STANGLAND`.
#
# Store the corresponding values in the following variables:
#
# - `total_pay` — the employee's `TotalPay`
# - `job_title` — the employee's `JobTitle`

# %%
# Find the TotalPay and JobTitle for GREGORY STANGLAND
total_pay = ...
job_title = ...

# Display the results
print(f"TotalPay: {total_pay:.2f}")
print(f"JobTitle: {job_title}")

# %% [markdown]
# #### Question 1d — Answer
#
# - `TotalPay`: **[Your answer here]**
# - `JobTitle`: **[Your answer here]**
#
# ----

# %% [markdown]
# ### Question 1e — Identifying a Maximum
#
# Identify the employee record with the highest `TotalPay` in the dataset.
#
# Store the corresponding values in the following variables:
#
# - `name` — the employee's `EmployeeName`
# - `year` — the year in which the pay was recorded
# - `total_pay` — the employee's `TotalPay`

# %%
# Find the employee record with the highest TotalPay
name = ...
year = ...
total_pay = ...

# Display the results
print(f"EmployeeName: {name}")
print(f"Year: {year}")
print(f"TotalPay: {total_pay:.2f}")

# %% [markdown]
# #### Question 1e — Answer
#
# - Employee: **[Your answer here]**
# - Year: **[Your answer here]**
# - `TotalPay`: **[Your answer here]**
# ----

# %% [markdown]
# ### Question 1f — Grouped Aggregation
#
# Calculate the maximum `TotalPay` for each year in the dataset.
#
# Store the result in a Pandas Series named `max_annual_total_pay`, where:
#
# - the index contains the `Year`, and
# - the values contain the maximum `TotalPay` for each year.
#
# Sort the Series by year in ascending order.

# %%
# Calculate the maximum TotalPay for each year
max_annual_total_pay = ...

# Display the result
print(max_annual_total_pay)

# %% [markdown]
# #### Question 1f — Answer
#
# - 2011: **567595.43**
# - 2012: **362844.66**
# - 2013: **347102.32**
# - 2014: **471952.64**
# ---

# %% [markdown]
# ### Question 1g — Unique Values
#
# How many unique job titles are present in the dataset?
#
# Store the result in a variable named `unique_jobs`.

# %%
# Calculate the number of unique job titles
unique_jobs = ...

# Display the result
print(f"Number of unique job titles: {unique_jobs}")

# %% [markdown]
# #### Question 1g — Answer
#
# - Number of unique job titles: **[Your answer here]**
# ---

# %% [markdown]
# ### Question 1h — Frequency Counts
#
# What are the five most common job titles in the dataset?
#
# Store the result in a Pandas Series named `top_5_job_counts`, where:
#
# - the index contains the `JobTitle`,
# - the values contain the number of occurrences of each job title, and
# - the results are ordered from most to least frequent.

# %%
# Identify the five most common job titles
top_5_job_counts = ...

# Display the result
print(top_5_job_counts)

# %% [markdown]
# #### Question 1h — Answer
#
# 1. **[Job title]** — **[Number of records]**
# 2. **[Job title]** — **[Number of records]**
# 3. **[Job title]** — **[Number of records]**
# 4. **[Job title]** — **[Number of records]**
# 5. **[Job title]** — **[Number of records]**
# ---

# %% [markdown]
# ### Question 1i — Conditional Frequency Counts
#
# Among the records from 2014, how many distinct job titles appear exactly once?
#
# Store the result in a variable named `num_jobs`.

# %%
# Count the job titles that appear exactly once in 2014
num_jobs = ...

# Display the result
print(f"Number of job titles appearing exactly once in 2014: {num_jobs}")

# %% [markdown]
# #### Question 1i — Answer
#
# - Number of job titles appearing exactly once in 2014: **[Your answer here]**
# ---

# %% [markdown]
# ### Question 1j — Text-Based Filtering
#
# Among the records from 2013, how many have a `JobTitle` containing the word `Chief`?
#
# Perform the search without regard to capitalization and store the result in a variable named `num_jobs_chief`.

# %%
# Count 2013 records with "Chief" in the job title
num_jobs_chief = ...

# Display the result
print(f'Number of 2013 job titles containing "Chief": {num_jobs_chief}')

# %% [markdown]
# #### Question 1j — Answer
#
# - Number of 2013 records with `Chief` in the job title: **[Your answer here]**
# ---
# ---

# %% [markdown]
# ## Question 2 — Wine Reviews
#
# For Question 2, you will work with the **Winemag Wine Reviews** dataset from Kaggle. The dataset contains approximately 130,000 wine reviews, including information about each wine's origin, variety, price, rating, reviewer, and description.
#
# Use Pandas to read `winemag_data.csv` into a DataFrame named `wine_reviews`. Preview the first five rows and inspect the structure of the DataFrame before proceeding to Question 2a.

# %%
# Load the dataset
wine_reviews = ...

# Preview the first five rows
wine_reviews.head()

# %%
# Display a summary of the DataFrame structure and data types
...

# %% [markdown]
# ### Question 2a — Reviewer Activity
#
# How many reviews are associated with each reviewer based on their `taster_twitter_handle`?
#
# Store the result in a Pandas Series named `reviewers`, where:
#
# - the index contains the `taster_twitter_handle`,
# - the values contain the number of reviews associated with each handle, and
# - the results are ordered from most to least reviews.
#
# Exclude missing Twitter handles.

# %%
# Count the number of reviews associated with each Twitter handle
reviewers = ...

# Display the five most active reviewers
reviewers.head()

# %% [markdown]
# #### Question 2a — Answer
#
# 1. **[Twitter handle]** — **[Number of reviews]**
# 2. **[Twitter handle]** — **[Number of reviews]**
# 3. **[Twitter handle]** — **[Number of reviews]**
# 4. **[Twitter handle]** — **[Number of reviews]**
# 5. **[Twitter handle]** — **[Number of reviews]**
# ---

# %% [markdown]
# ### Question 2b — Grouped Aggregation by Price
#
# For each wine price, determine the maximum review score (`points`) observed at that price.
#
# Store the result in a Pandas Series named `price_max_points`, where:
#
# - the index contains the `price`,
# - the values contain the maximum `points` for each price, and
# - the index is sorted by price in descending order.

# %%
# Calculate the maximum review score for each price
price_max_points = ...

# Display the five highest-priced entries
price_max_points.head()

# %% [markdown]
# #### Question 2b — Answer
#
# 1. Price: **[Your answer here]** — Maximum score: **[Your answer here]**
# 2. Price: **[Your answer here]** — Maximum score: **[Your answer here]**
# 3. Price: **[Your answer here]** — Maximum score: **[Your answer here]**
# 4. Price: **[Your answer here]** — Maximum score: **[Your answer here]**
# 5. Price: **[Your answer here]** — Maximum score: **[Your answer here]**
# ---

# %% [markdown]
# ### Question 2c — Text Analysis
#
# What percentage of wine review descriptions contain either the term `fruity` or the term `tart`?
#
# Perform the search without regard to capitalization and treat missing descriptions as not containing either term.
#
# Store the result as a percentage in a variable named `fruity_tart_percentage`.

# %%
# Calculate the percentage of descriptions containing "fruity" or "tart"
fruity_tart_percentage = ...

# Display the result
print(f'Percentage of descriptions containing "fruity" or "tart": {fruity_tart_percentage:.2f}%')

# %% [markdown]
# #### Question 2c — Answer
#
# - Percentage of descriptions containing `fruity` or `tart`: **[Your answer here]%**
# ---

# %% [markdown]
# ### Question 2d — Text Analysis by Country
#
# For each country, count the number of review descriptions that contain either the term `fruity` or the term `tart`.
#
# Use the same text-matching rules as in Question 2c.
#
# Store the result in a Pandas Series named `fruity_tart_count_by_country`, where:
#
# - the index contains the `country`,
# - the values contain the number of matching review descriptions, and
# - the results are ordered from highest to lowest count.

# %%
# Count descriptions containing "fruity" or "tart" for each country
fruity_tart_count_by_country = ...

# Display the five countries with the highest counts
fruity_tart_count_by_country.head()

# %% [markdown]
# #### Question 2d — Answer
#
# 1. **[Country]** — **[Number of matching descriptions]**
# 2. **[Country]** — **[Number of matching descriptions]**
# 3. **[Country]** — **[Number of matching descriptions]**
# 4. **[Country]** — **[Number of matching descriptions]**
# 5. **[Country]** — **[Number of matching descriptions]**
# ---

# %% [markdown]
# ### Question 2e — Unique Varieties by Country
#
# For each country, determine the number of unique wine varieties represented in the dataset.
#
# Store the result in a Pandas Series named `country_varieties_count`, where:
#
# - the index contains the `country`,
# - the values contain the number of unique wine varieties, and
# - the results are ordered from highest to lowest count.

# %%
# Count the number of unique wine varieties for each country
country_varieties_count = ...

# Display the five countries with the most unique varieties
country_varieties_count.head()

# %% [markdown]
# #### Question 2e — Answer
#
# 1. **[Country]** — **[Number of unique varieties]**
# 2. **[Country]** — **[Number of unique varieties]**
# 3. **[Country]** — **[Number of unique varieties]**
# 4. **[Country]** — **[Number of unique varieties]**
# 5. **[Country]** — **[Number of unique varieties]**
# ---

# %% [markdown]
# ### Question 2f — Country and Variety Combinations
#
# Which combinations of country and wine variety occur most frequently in the dataset?
#
# Store the result in a Pandas Series named `country_varieties`, where:
#
# - the index is a MultiIndex containing (`country`, `variety`) pairs,
# - the values contain the number of records for each country–variety combination, and
# - the results are ordered from highest to lowest count.

# %%
# Count the frequency of each country–variety combination
country_varieties = ...

# Display the five most common combinations
country_varieties.head()

# %% [markdown]
# #### Question 2f — Answer
#
# 1. **[Country]** — **[Variety]** — **[Number of records]**
# 2. **[Country]** — **[Variety]** — **[Number of records]**
# 3. **[Country]** — **[Variety]** — **[Number of records]**
# 4. **[Country]** — **[Variety]** — **[Number of records]**
# 5. **[Country]** — **[Variety]** — **[Number of records]**
# ---
# ---

# %% [markdown]
# ## Before You Submit
#
# You have completed **Assignment 1 — Pandas**.
#
# ### Assignment Files
#
# You can access this week's assignment using the link below:
#
# [**Open Assignment 1 in JupyterHub**](https://jupyter.utoronto.ca/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2FCME538%2FCME538-material&urlpath=lab%2Ftree%2FCME538-material%2Fassignments%2Fassignment1%2Fassignment1.ipynb&branch=master)
#
# Alternatively, you can download the **Assignment 1 package** from Quercus.
#
# ### Final Checklist
#
# Before submitting your assignment:
#
# - Review your answers for completeness and accuracy.
# - Remove unnecessary scratch cells and outputs.
# - Ensure that all requested variables use the specified names.
# - Confirm that your final answers are clearly reported in the designated answer cells.
# - Restart the kernel and run the notebook from beginning to end to ensure that all cells execute without errors.
# - Review your code for clarity, readability, and unnecessary operations.
#
# ### Submission
#
# Submit **both** your completed Jupyter Notebook (`.ipynb`) and an exported HTML (`.html`) version through Quercus.
#
# Use the following filenames:
#
# - `firstname_lastname_studentnumber.ipynb`
# - `firstname_lastname_studentnumber.html`
#
# Ensure that the HTML file contains all code, outputs, and written answers before submitting.
